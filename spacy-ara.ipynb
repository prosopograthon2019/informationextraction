# %%
import json
import math
from pprint import pprint
import random
import spacy

from spacy.util import minibatch, compounding

# %%
# loads the training data
train_file = open('training/json/0748Dhahabi.TarikhIslam.Shamela0035100-ara1.csv.json')
data = json.load(train_file)
size_of_data = len(data)

pprint(size_of_data)
pprint(data[:3])
# Out:
# 20107
# [['الشأن وتلاحق المهاجرون الذين تأخروا بمكة بالنبي صلى الله عليه وسلم',
#   {'entities': [[36, 40, 'LOC']]}],
#  ['بن وائل السهمي والد عمرو بمكة على الكفر وكذلك أبو أحيحة',
#   {'entities': [[25, 29, 'LOC']]}],
#  ['وسلم حارثة وأبا رافع إلى مكة لينقلا بناته وسودة أم المؤمنين',
#   {'entities': [[25, 28, 'LOC']]}]]

# %%
# randomises the data
random.shuffle(data)

# %%
# splits the data into training and testing sets
threshold = math.floor(size_of_data * .9)

train_data = data[:threshold]
test_data = data[threshold:]

# %%
# creates a blank model of greek, it doesn't recognise the ancient greek code grc
nlp = spacy.blank('ar')
ner = nlp.create_pipe('ner')
nlp.add_pipe(ner)

# %%
# adds the entity types we want to identify
for item in data:
    for entity in item[1]['entities']:
        ner.add_label(entity[2])

# %%
# initialises a pipeline for training
optimizer = nlp.begin_training()
# Out:
# Warning: Unnamed vectors -- this won't allow multiple vectors models to be loaded. (Shape: (0, 0))

# %%
# trains the model
for i in range(1):
    print('# Iteration', i)
    
    random.shuffle(train_data)
    losses = {}
    
    batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        nlp.update(
            texts,  # batch of texts
            annotations,  # batch of annotations
            drop=0.5,  # dropout - make it harder to memorise data
            losses=losses,
        )

    print('Losses', losses)
# Out:
# Iteration # 0
# Losses {'ner': 144.85930563754022}
# Iteration # 1
# Losses {'ner': 5.258088229333444}
# Iteration # 2
# Losses {'ner': 3.588416440092322}
# Iteration # 3
# Losses {'ner': 1.071326352099852}
# Iteration # 4
# Losses {'ner': 2.293773869451867}

# %%
# tests the trained model
c_true_positives = 0
c_false_positives = 0
c_expected = 0

for text, entities in test_data:
    doc = nlp(text)
    
    expected = [
        (text[ent[0]:ent[1]], ent[2]) for ent in entities['entities']
    ]
    expected_len = len(expected)
    
    entities = [
        (ent.text, ent.label_) for ent in doc.ents
    ]
    entities_len = len(entities)
    
    print('#', text)
    print('Expected Entities', expected)
    print('Entities', entities)
    
    matches = 0
    for ent in entities:
        if ent in expected:
            matches += 1
    
    print('Matched', matches, 'out of', expected_len)
    
    c_true_positives += matches
    c_false_positives += (entities_len - matches)
    c_expected += len(expected)
    
    print()

# precision is the number of correct results divided by the number of all returned results
print('% Precision', c_true_positives / (c_true_positives + c_false_positives))

# recall is the number of correct results divided by the number of results that should have been returned
print('% Recall', c_true_positives / c_expected)
# Out:
# Text النهرفضلي البصري الوفاة ه نزيل بغداد شيخ صالح قرأ طرفا من
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text التميمي الأديب الوفاة ه توفي بهراة في رجب  صاعد بن
# Expected Entities [('بهراة', 'LOC')]
# Entities [('بهراة', 'LOC')]
# 1  out of  1
#
# Text بن عتاب وكان أسند من بالأندلس في زمانه توفي في عاشر
# Expected Entities [('بالأندلس', 'LOC')]
# Entities [('بالأندلس', 'LOC')]
# 1  out of  1
#
# Text وهؤلاء وأبا علي التستري وجماعة بالبصرة ثم سمع ببغداد ما لا
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text الطرسوسي الزاهد الوفاة ه نزيل دمشق روى عن الفضيل بن عياض
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text وأعجب به وأمره وبعثه إلى دمشق في سنة ست وأربع مائة
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text إبراهيم الجزري المعروف بالجبيلي اشتراه بدمشق ورباه ثم باعه بألف دينار
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text محمد وجماعة وحج فقرأ القراءات بمكة على أبي معشر الطبري وسمع
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text من أهل  الجزيرة فقدم بغداد وامتدح الرشيد وغيره وجرت بينه
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text التاسع عشر من جمادى الآخرة ببغداد وهو منسوب إلى القادسية التي
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text مروان بن معاوية الفزاري نزيل دمشق نصر بن باب الخراساني بها
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الكلاع إلى المختار فأرسلها فنصبت بمكة وممن قتل مع إبراهيم هبيرة
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text وحج وتوسع في الرحلة وقدم دمشق فسمع بها الكثير من أبي
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الري وكان قد سار من دمشق إلى خراسان عندما سمع بموت
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text سنة ثمان وخمسمائة انهزم وسكن قرطبة وابنه أبو محمد عبد العزيز
# Expected Entities [('قرطبة', 'LOC')]
# Entities [('قرطبة', 'LOC')]
# 1  out of  1
#
# Text حدثنا محمد بن نوح الأصبهاني بمكة قال حدثنا أبو القاسم الطبراني
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text عصره وإمام زمانه لم أر بالأندلس مثله وقال ابن عبد البر
# Expected Entities [('بالأندلس', 'LOC')]
# Entities [('بالأندلس', 'LOC')]
# 1  out of  1
#
# Text ست وسبعين وستمائة دخل السلطان دمشق في سابع المحرم فدخل القلعة
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text إبراهيم المسجدي والفراوي وبسرخس وبلخ وبغداد وغيرها وعنه الحافظ عبد القادر
# Expected Entities [('وبغداد', 'LOC')]
# Entities [('وبغداد', 'LOC')]
# 1  out of  1
#
# Text قال ولحق كعب بن الأشرف بمكة إلى أن قدم المدينة معلنا
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text خادما لهما فلما عدنا إلى الكوفة قال يحيى أريد أختبر أبا
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text ورحل مع ابنه قاسم فسمعا بمكة من محمد بن علي الجوهري
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text وغيرهم وهو والد الفتح مسند بغداد في زمانه توفي في تاسع
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text عنه شيئا وتوفي في شعبان بإسفرايين  علي بن نصر بن
# Expected Entities [('بإسفرايين', 'LOC')]
# Entities [('بإسفرايين', 'LOC')]
# 1  out of  1
#
# Text وعشرين ومائتين وقال الخطيب سكن بغداد ثم جاور بمكة  د
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text سبع وخمس مائة ومات بمالين هراة في ثاني عشر شوال سنة
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text قضاء عسكره بفم الصلح ومات بالمبارك سنة إحدى ومائتين ولهثلاث وستون
# Expected Entities [('بالمبارك', 'LOC')]
# Entities [('بالمبارك', 'LOC')]
# 1  out of  1
#
# Text وجماعة وثقه الدارقطني وغيره ومات بأنطاكية عند قدومه من مكة سنة
# Expected Entities [('بأنطاكية', 'LOC')]
# Entities [('بأنطاكية', 'LOC')]
# 1  out of  1
#
# Text سعيد وأبو المعالي ابن الشعيري بدمشق والقاضي أبو بكر الأنصاري وأبو
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text بن مروان العنسي مات مطعونا بدمشق  مسلم بن عقبة الذي
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text الحسن بن موسى الغندجاني وقدم بغداد فقرأ بها على سليمان بن
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text من ثبت معه فوصلوا إلى أنطاكية فكانوا نيفا وأربعين ألفا فوقع
# Expected Entities [('أنطاكية', 'LOC')]
# Entities [('أنطاكية', 'LOC')]
# 1  out of  1
#
# Text له الحسن العسكري لكونه سكن سامراء فإنها يقال لها العسكر وهو
# Expected Entities [('سامراء', 'LOC')]
# Entities [('سامراء', 'LOC')]
# 1  out of  1
#
# Text العزيز بن منينا وطائفة وبالري والموصل وتكريت وإربل وحلب وحران وعاد
# Expected Entities [('والموصل', 'LOC')]
# Entities [('والموصل', 'LOC')]
# 1  out of  1
#
# Text طلبه وطوى الممالك حتى نازل دمشق وحاصرها وتملكها وافتتحها بالسيف وعمل
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text وكان يسكن بسكة النعيمية محلة ببغداد وتوفي في الثاني والعشرين من
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بن طبرزد توفي في رجب بكفرطاب  مسعود بن عبد الله
# Expected Entities [('بكفرطاب', 'LOC')]
# Entities [('بكفرطاب', 'LOC')]
# 1  out of  1
#
# Text بن الزكي وتصدر للإقراء بجامع دمشق وكان رجلا صالحا توفي في
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الدين محمد بن أيتمش وصاحب كرمان خاتون زوجة الحاجب براق وصاحب
# Expected Entities [('كرمان', 'LOC')]
# Entities [('كرمان', 'LOC')]
# 1  out of  1
#
# Text الإسكندراني الكاتب الوفاة ه قدم دمشق وسمع من الكندي وابن الحرستاني
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الطليطلي الضرير الوفاة ه سمع بقرطبة من أحمد بن خالد ومحمد
# Expected Entities [('بقرطبة', 'LOC')]
# Entities [('بقرطبة', 'LOC')]
# 1  out of  1
#
# Text هيجت عكرمة على السير إلى إفريقية فلما قدمها اتهموه قال وكان
# Expected Entities [('إفريقية', 'LOC')]
# Entities [('إفريقية', 'LOC')]
# 1  out of  1
#
# Text الأسعد هبة الرحمن القشيري وسمع ببغداد من الحسين بن نصر بن
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text وهو ابن ثلاث وأربعين فمكث بمكة عشرا وبالمدينة عشرا وقال محمد
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text واليمانية يمرون بالدار من دور دمشق فتقول ريح قيسي تشم من
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text صدر جهان قد صار إلى بغداد ومعه جمع من الفقهاء وواحد
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text النقور مات ليلة نصف شعبان ببغداد روى عنه عمر بن ظفر
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text في رؤوس  الجبال وخلوا مكة وقال معمر عن الزهري عن
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text من الحجاج وقد ولي نيابة دمشق عدة أمراء للحاكم في هذه
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text بن علي بن عيسى الرازي ببغداد قال حدثنا موسى بن ص
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text ظاهرا وقت خروجه معي إلى أصبهان فقال لي أخوه وجيه يا
# Expected Entities [('أصبهان', 'LOC')]
# Entities [('أصبهان', 'LOC')]
# 1  out of  1
#
# Text القتال إلى الليل ثم حاصروه بمكة شهر صفر ورموه بالمنجنيق وكانوا
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text المصري صاحب كريمة المروزية وسمع ببغداد من أبي القاسم بن الحصين
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text النسائي منه فإنه إنما قدم نيسابور سنة خمس أو ست
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text ومحمد بن سليمان الباغندي وخلقا ببغداد وغيرها وعنه الدارقطني والحاكم وابن
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text شيخ الشافعية وأخوه الشرف خطيب دمشق والبدر ابن الخلال والشمس محمد
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text عن أبيه قال ما أخرجت خراسان مثل محمد بن إسماعيل وقال
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text في سنة إحدى وسبعين ومائتين بنيسابور صحبه الشيخ عبد الله بن
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text الله بن عمرو قال كنت بالبصرة أنتظر قدوم أيوب من مكة
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text أنه يستخلص الأموال من أهل دمشق فصفعه الصالح وحبسه وحبس الوزير
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text جويرية له صحبة ورواية نزل الكوفة وروى أيضا عن ابن مسعود
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text والأخبار وكان زيدي المذهب وفسر بمصر القرآن في سبع مائة مجلد
# Expected Entities [('بمصر', 'LOC')]
# Entities [('بمصر', 'LOC')]
# 1  out of  1
#
# Text وعمر بن أحمد بن شاهين بسمرقند وقال أبو سعد الإدريسي توفي
# Expected Entities [('بسمرقند', 'LOC')]
# Entities [('بسمرقند', 'LOC')]
# 1  out of  1
#
# Text المظفر وجماعة وكان ثقة توفي بالشاش أرخه الخطيب ونعته بالحفظ الخليلي
# Expected Entities [('بالشاش', 'LOC')]
# Entities [('بالشاش', 'LOC')]
# 1  out of  1
#
# Text المري من الحرة توجه إلى مكة واستخلف على المدينة روح بن
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text إلى ابن خاقان ليدفعه عن أردبيل فالتقى الجمعان وعظم القتال واشتد
# Expected Entities [('أردبيل', 'LOC')]
# Entities [('أردبيل', 'LOC')]
# 1  out of  1
#
# Text بيت بالمنارة الشرقية من جامع دمشق وخزانة كتب تجاه محراب الصحابة
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text وأخرج بديرا ثم ولي بدير دمشق بعد ذلك من قبل كافور
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text طلب العلم حتى سافر إلى بغداد وأصبهان مرات كثيرة ماشيا وكان
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text معز الدوله أحمد بن بويه بغداد فلما نزل باجسرى استتر المستكفي
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text الهيثم ولاهز وقحطبة توجهوا من خراسان إلى الحج سنة أربع وعشرين
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text وعلي بن الحسين الأدمي نزل أنطاكية  يعقوب بن يوسف بن
# Expected Entities [('أنطاكية', 'LOC')]
# Entities [('أنطاكية', 'LOC')]
# 1  out of  1
#
# Text نفثة راق قالوا توفي المغيرة بالكوفة أميرا عليها سنة خمسين زاد
# Expected Entities [('بالكوفة', 'LOC')]
# Entities [('بالكوفة', 'LOC')]
# 1  out of  1
#
# Text ولد سنة خمس عشرة وخمسمائة ببغداد ولو سمع الحديث في صغره
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text وهو أعلى شيخ له لقيه بمكة وكتب عنه جزءا من حديثه
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text إماما فيه وإليه كانت الرحلة بالأندلس وولي خطابة بلده ويعرف بابن
# Expected Entities [('بالأندلس', 'LOC')]
# Entities [('بالأندلس', 'LOC')]
# 1  out of  1
#
# Text دائم البكاء كثير الحزن جاور بمكة مدة توفي في ربيع الأول
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text وأمه أم ولد ولي إمرة الكوفة سنة أربع ومائتين وحج بالناس
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text ممن عدم في دخول العدو هراة  محمود بن محمد بن
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text عسكر الخليفة ونودي لا يبقى ببغداد أحد من العسكر وخرج الراشد
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text وفد على معاوية لما دخل الكوفة روى عنه ابناه علقمة وعبد
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text الخزاعي البوشنجي الوفاة ه حدث ببغداد ونيسابور عن أبي نعيم والقعنبي
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text خرج على إقليم فارس فصلب بالبصرة بعد قطع أربعته ثم عزل
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text الوفاة ه من محلة البدرية ببغداد سمع ابن ناصر وأبا الوقت
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text القاسم ابن البزري ثم تفقه ببغداد بالنظامية وسمع من الكروخي ودرس
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بن نصر وخلق غيرهم وتوفي بقرطبة في جمادى الأولى  القاسم
# Expected Entities [('بقرطبة', 'LOC')]
# Entities [('بقرطبة', 'LOC')]
# 1  out of  1
#
# Text رأي ولسان وعارضة وبيان قدم بغداد رسولا غير مرة وروى بها
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text استولى ألبان صاحب عكا على أنطاكية وشن الغارات على التركمان وشردهم
# Expected Entities [('أنطاكية', 'LOC')]
# Entities [('أنطاكية', 'LOC')]
# 1  out of  1
#
# Text في القتال أقيمت السكة والخطبة بدمشق أياما لرضوان ثم استقر على
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text على هلاكه فسلموا إليه الصبيبة وبانياس وبقي في خدمة نائب دمشق
# Expected Entities [('وبانياس', 'LOC')]
# Entities [('وبانياس', 'LOC')]
# 1  out of  1
#
# Text بالعربية سمع منه غير واحد بقرطبة وعمر دهرا توفي ابن ثمان
# Expected Entities [('بقرطبة', 'LOC')]
# Entities [('بقرطبة', 'LOC')]
# 1  out of  1
#
# Text حج وسمع من ابن الحصين ببغداد وحدث بإشبيلية  أنوشتكين بن
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text من نهار ونادى أبو سفيان بمكة أسلموا تسلموا فكفهم الله عن
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text بن زكريا المحاربي وخلق وسمع بدمشق من شعيب بن إسحاق وعنه
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text روى عنه خلق من علماء الأندلس وانتفعوا به وبعلمه وبفضله ونال
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text فإنه كان عامل معاوية على الكوفة فكتب إليه معاوية إذا قرأت
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text منهم أبو القاسم الهذلي وتوفي بنيسابور في رمضان وقال عبد الغافر
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text الأزد فأجاره ثم إن أهل البصرة بايعوا عبد الله بن الحارث
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text قال ابن السمعاني خرج إلى أصبهان من بغداد فنزل قرية بين
# Expected Entities [('أصبهان', 'LOC')]
# Entities [('أصبهان', 'LOC')]
# 1  out of  1
#
# Text للحملة وولوا منهزمين وتبعهم عسكر دمشق وأما أهل البلد فإنهم قتلوا
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text بالقدس في شوال وصلي عليه بدمشق صلاة الغائب  عمر بن
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text إليها قبل وفاته بأيام وسكن خوارزم مدة ثم بلخ وكان إماما
# Expected Entities [('خوارزم', 'LOC')]
# Entities [('خوارزم', 'LOC')]
# 1  out of  1
#
# Text ذلك وتوفي في ذي القعدة بقرطبة  بشرويه بن محمد بن
# Expected Entities [('بقرطبة', 'LOC')]
# Entities [('بقرطبة', 'LOC')]
# 1  out of  1
#
# Text المغربي الوفاة ه من شيوخ بغداد تفقه على أبي إسحاق وأبي
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text قال فكنت في جيش الملك خوارزم شاه ومعه يومئذ مقدار ستمائة
# Expected Entities [('خوارزم', 'LOC')]
# Entities [('خوارزم', 'LOC')]
# 1  out of  1
#
# Text العز بن كادش ثم قدم دمشق فسكنها مدة وأقرأ بها القرآن
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text دينا عالما فاضلا جليلا توفي بدمشق في حادي عشر شوال بخانكاه
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text الأعز وفيها كانت فتنة هائلة ببغداد بين السنة والشيعة أدت إلى
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text مالك وسفيان وقال ما رأيت بالبصرة أفقه منه وعن حماد بن
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text رضوان في الخطبة على أخيه بدمشق واصطلحا وفيها خطب للمستعلي بالله
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text سيرين وغيرهما وقد ولي قضاء البصرة قال خليفة وفي سنة ثلاث
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text ما فاته الصلاة في جامع هراة نحوا من أربعين سنة سمع
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text في آخر خلافة معاوية إلى البصرة فأقام بها يظهر ذكر الحسين
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text العباس العلوي وكان شيخ الشيوخ بإصبهان في زمانه أعني أبا سعيد
# Expected Entities [('بإصبهان', 'LOC')]
# Entities [('بإصبهان', 'LOC')]
# 1  out of  1
#
# Text رسول الله وطافوا بها في بغداد وجميع من حولها يعلن بالشهادتين
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text الباجسرائي وتوفي في ذي الحجة ببغداد  إسحاق الملك المعز أبو
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text ثمان وثلاثين مدينة من مدائن خوارزم بينها وبين المدينة العظمى نصف
# Expected Entities [('خوارزم', 'LOC')]
# Entities [('خوارزم', 'LOC')]
# 1  out of  1
#
# Text سنة ست وتسعين وفيها ظهر بدمشق الداعي العجمي المدعي أنه عيسى
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text ودبر مملكته فلما غلب على دمشق استقل بتدبير المملكة وحصل لمخدومه
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text المكارم اللبان وأبي جعفر الصيدلاني وبنيسابور من أبي سعد عبد الله
# Expected Entities [('وبنيسابور', 'LOC')]
# Entities [('وبنيسابور', 'LOC')]
# 1  out of  1
#
# Text المائة سمع يحيى بن عبدك بقزوين وعباسا الدوري وحنبل بن إسحاق
# Expected Entities [('بقزوين', 'LOC')]
# Entities [('بقزوين', 'LOC')]
# 1  out of  1
#
# Text به كان الناس يقصدونه من الموصل وبغداد وسنجار  والجزيرة وغيرها
# Expected Entities [('الموصل', 'LOC')]
# Entities [('الموصل', 'LOC')]
# 1  out of  1
#
# Text خرج في ربيع الأول من بغداد وكانت إقامته بها سنة وسبعة
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text ابن تاشفين وقف له بجامع مراكش محمد بن تومرت الفقيه وكلمه
# Expected Entities [('مراكش', 'LOC')]
# Entities [('مراكش', 'LOC')]
# 1  out of  1
#
# Text عسكر ابن المهدي فإن أهل الكوفة شيعتكم وأنا معك فلما كان
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text وتسمى بالخلافة وقوي أمره وملك قرطبة مرة ثانية وتسلم الحصون والقلاع
# Expected Entities [('قرطبة', 'LOC')]
# Entities [('قرطبة', 'LOC')]
# 1  out of  1
#
# Text سمعت من يزيد بن هارون ببغداد وكان يقال إن في مجلسه
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text وقال شيرويه الديلمي في تاريخ همذان أبو إسحاق الشيرازي إمام عصره
# Expected Entities [('همذان', 'LOC')]
# Entities [('همذان', 'LOC')]
# 1  out of  1
#
# Text البهزي الوفاة ه صحابي نزل البصرة ثم سكن الأردن له أحاديث
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text الصلاة حسن الطريقة خشنها لقيته بأصبهان وسمعت منه الكثير وما دخلت
# Expected Entities [('بأصبهان', 'LOC')]
# Entities [('بأصبهان', 'LOC')]
# 1  out of  1
#
# Text الحسن الصنعاني بعد العشرين وأربعمائة بمكة ذكره حمزة السهمي أن رفيقه
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text يقدم من قريته كاذة إلى بغداد فيحدث ويرجع أخبرنا أبو الفهم
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text وتسكينها وفيها سار غازان إلى بغداد وجهز عسكرا إلى البطائح فأوقعوا
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text العلوي الحسني الوفاة ه صاحب مكة كان ظالما جبارا صادر المجاورين
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text صودر أطلق سراحه فانتقل إلى ميافارقين وقد باضت الرياسة في رأسه
# Expected Entities [('ميافارقين', 'LOC')]
# Entities [('ميافارقين', 'LOC')]
# 1  out of  1
#
# Text محمد الديلمي الوفاة ه حدث ببغداد عن أحمد بن محمد بن
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text الأمير منكورس إلى السلطان وهو بدمشق فسأله السلطان وقرره بلطف حتى
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text وفيها فتحت المدرسة التي بنيت ببغداد لوالدة الناصر لدين الله ودرس
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text سنة أربع وخمسين أصله من الصغد واسم أبيه منصور لا أعلم
# Expected Entities [('الصغد', 'LOC')]
# Entities [('الصغد', 'LOC')]
# 1  out of  1
#
# Text تقطع في ريبة فلما قدم بغداد وناظر المجير وكان كثيرا ما
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text عبد الرحمن الوفاة ه قاضي نيسابور كناه الحاكم سمع في رحلته
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text وقال يوسف الرعيني أجمع العلماء بالقيروان على أن حال بني عبيد
# Expected Entities [('بالقيروان', 'LOC')]
# Entities [('بالقيروان', 'LOC')]
# 1  out of  1
#
# Text صلى الله عليه وسلم قدم مكة والمشركون على قعيقعان وكان أهل
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text العادل الوفاة ه صاحب الصبيبة وبانياس توفي أبوه سنة ثلاثين فقام
# Expected Entities [('وبانياس', 'LOC')]
# Entities [('وبانياس', 'LOC')]
# 1  out of  1
#
# Text بمؤونتهم وكسوتهم فلما خرج إلى خراسان انقطعت الرواتب من المؤونة وبقيت
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text التاجر السفار الوفاة ه سكن بنيسابور مدة وحدث عن أبي علي
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text عمي وجماعة وتوفي في شعبان بنيسابور وهو مقرئ صالح ثقة قال
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text يدركوه وفرح الخادم بقدومه وتملك دمشق واتفق مجيء طغتكين هو وجماعة
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text والذخائر حتى ولي تدريس النظامية ببغداد قال ابن السمعاني خرج عنه
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بالعراق وقال الفسوي ولي موسى إفريقية سنة تسع وسبعين فافتتح بلادا
# Expected Entities [('إفريقية', 'LOC')]
# Entities [('إفريقية', 'LOC')]
# 1  out of  1
#
# Text وإبراهيم بن محمد القفال وطائفة وبنيسابور من الفضل بن المحب وموسى
# Expected Entities [('وبنيسابور', 'LOC')]
# Entities [('وبنيسابور', 'LOC')]
# 1  out of  1
#
# Text الجوزي في تاريخه اجتمع قاضي دمشق محيي الدين والخطيب ضياء الدين
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text حصن القصير وهو بين حارم وأنطاكية وكان فيه قسيس عظيم يقصد
# Expected Entities [('وأنطاكية', 'LOC')]
# Entities [('وأنطاكية', 'LOC')]
# 1  out of  1
#
# Text رحل وطوف في الحديث فسمع بمكة أبا سعيد ابن الأعرابي وبالبصرة
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text في سابع عشر ذي القعدة ببيت المقدس ودفن بباب الرحمة ومولده
# Expected Entities [('ببيت', 'LOC')]
# Entities [('ببيت', 'LOC')]
# 1  out of  1
#
# Text بذلك وهو الذي أنشأ مدينة مراكش وفي يوم عاشوراء قتل فخر
# Expected Entities [('مراكش', 'LOC')]
# Entities [('مراكش', 'LOC')]
# 1  out of  1
#
# Text السجستاني الصوفي الوفاة ه قدم هراة وأدرك بها شيخ الإسلام أبا
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text البغدادي الحافظ الوفاة ه سمع بدمشق محمد بن يوسف الهروي والحسن
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text الطائع لله أخباره في تاريخ دمشق وفي الحوادث  الحسن بن
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text فلما اشتد الأمر على أهل بغداد وأظهرت القضاة المحنة وفرق بين
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text عتبة أخو معاوية وفيها غزا إفريقية عقبة بن نافع الفهري وفيها
# Expected Entities [('إفريقية', 'LOC')]
# Entities [('إفريقية', 'LOC')]
# 1  out of  1
#
# Text الضرير وجماعة توفي سنة عشرين بدمشق وقال الواقدي دفن بباب الصغير
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text السلام بن محمد المؤدب وأهل هراة وعاش نحوا من تسعين سنة
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text بن محبوب وببغداد البغوي وطبقته وبنيسابور مؤمل بن الحسن وأبا عمرو
# Expected Entities [('وبنيسابور', 'LOC')]
# Entities [('وبنيسابور', 'LOC')]
# 1  out of  1
#
# Text انهزم منكلي الذي غلب على همذان وأصبهان والري فقتل واستقرت القواعد
# Expected Entities [('همذان', 'LOC')]
# Entities [('همذان', 'LOC')]
# 1  out of  1
#
# Text بن أحمد الأرتاحي وغيره وتوفي بمكة في حدود سنة تسعين
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text الفضل أحمد بن سعد وحدث ببغداد ومكة ودمشق روى عنه علي
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بندار الشعار والعسال ورحل فسمع بنيسابور وهراة وجرجان والبصرة ولحق إسماعيل
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text ميدان زياد الذي على باب نيسابور سكن همذان روى عن محمد
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text سنيا أديبا شاعرا ومجلسه بجامع قرطبة للوعظ في غاية الحفل كانوا
# Expected Entities [('قرطبة', 'LOC')]
# Entities [('قرطبة', 'LOC')]
# 1  out of  1
#
# Text وبين أخيه السلطان محمود بقرب همذان فكانت النصرة لمحمود وانهزم مسعود
# Expected Entities [('همذان', 'LOC')]
# Entities [('همذان', 'LOC')]
# 1  out of  1
#
# Text وأكثر إلى أن ضعف أهل بغداد وذلوا من الجوع والجهد وقوي
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text فيه وحللت عني وقال كنت ببغداد في أول الرحلة الثانية من
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text البالسي الفقيه الوفاة ه قدم بغداد وتفقه على أبي بكر الشاشي
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text الصاغاني سمعت قتيبة يقول فتيان خراسان أربعة زكريا بن يحيى اللؤلؤي
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text العملة المشهورة من مخزن الأيتام بقيسارية الفرش لأيتام الأمير سيف الدين
# Expected Entities [('بقيسارية', 'LOC')]
# Entities [('بقيسارية', 'LOC')]
# 1  out of  1
#
# Text الأرتاحي وغيرهم وأجاز له من بغداد أبو الفرج بن كليب وأبو
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text الدين ابن خلكان انحدر إلى بغداد وأعاد بها ثم مضى إلى
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text العكبري وجماعة من بغداد وحدث بدمشق لما قدمها للحج وكان محدثا
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text ورزق الله بن عبد الوهاب وبأصبهان أبا منصور محمد بن علي
# Expected Entities [('وبأصبهان', 'LOC')]
# Entities [('وبأصبهان', 'LOC')]
# 1  out of  1
#
# Text يدركوه وسار على البرية ودخل بغداد ثم مضى إلى شيراز فمدح
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text المغيرة بن شعبة وهو على الكوفة يذكر له غلاما عنده صنعا
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text الأنطاكي وأقرأ الناس في مسجده بقرطبة زمانا ثم نقله يونس بن
# Expected Entities [('بقرطبة', 'LOC')]
# Entities [('بقرطبة', 'LOC')]
# 1  out of  1
#
# Text وأربعين وكان من جلة العلماء ببغداد  خ الحسن بن خلف
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text القبض على الحلبي فخرجوا عن دمشق ونابذوه وفيهم علاء الدين البندقدار
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text وأبا عثمان المغربي وجماعة سواهم بنيسابور ورحل إليه من البلاد وحدث
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text أبو الفضل الوفاة ه صاحب سجستان قال ابن الأثير عمر مائة
# Expected Entities [('سجستان', 'LOC')]
# Entities [('سجستان', 'LOC')]
# 1  out of  1
#
# Text بدار الكاس وقد ولي إمرة الموصل  والجزيرة للوليد بن يزيد
# Expected Entities [('الموصل', 'LOC')]
# Entities [('الموصل', 'LOC')]
# 1  out of  1
#
# Text مناقب الشافعي وآبر من قرى سجستان توفي في شهر رجب
# Expected Entities [('سجستان', 'LOC')]
# Entities [('سجستان', 'LOC')]
# 1  out of  1
#
# Text والبرك أكتع أأخرجتني من بطن مكة أيمنا وأسكنتني في سرح بيضاء
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text الزيدي قرأ عليه بحران وقرأ بدمشق على أبي علي الأهوازي وبمصر
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text ففرت بعبد الله أمه إلى مكة ونشأ بها وسمع من ابن
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text بن أرغون وكان متسلما ثغر خراسان عاصيا على الرجلين فلما بلغه
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text تورانشاه بن قاروت بك السلجوقي بكرمان قد قتل الإسماعيلية الأتراك أصحاب
# Expected Entities [('بكرمان', 'LOC')]
# Entities [('بكرمان', 'LOC')]
# 1  out of  1
#
# Text ابن خرشيذ قوله ورحل إلى بغداد فأدرك أبا نصر الزينبي وهو
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text على الحجاز واليمن ومصر والعراق وخراسان وأكثر الشام ولد سنة اثنتين
# Expected Entities [('وخراسان', 'LOC')]
# Entities [('وخراسان', 'LOC')]
# 1  out of  1
#
# Text جدهم أول من أظهر السنة بخراسان  جعفر بن محمد بن
# Expected Entities [('بخراسان', 'LOC')]
# Entities [('بخراسان', 'LOC')]
# 1  out of  1
#
# Text الوفاة ه ودردا من قرى بغداد رئيس متمول حدث عن أبي
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text أكثرهن ماشيا من المدينة إلى مكة وإن نجائبه تقاد معه وقال
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text أتباع له بها أمتعة من مكة وزبيد فلما قدمت إلى ذي
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text حيث يولد فإذا أضاف إلى خراسان ولادة همذان ارتفع القلم وسقط
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text بالموصل ونقل بعد سنة إلى مكة في تابوت فوقفوا به وطافوا
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text لما بقي بين التتار وبين بغداد يومين أعلم الخليفة حينئذ فقال
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text يوسف بن تاشفين البربري مدينة قرطبة وضايقها وآذى الناس فتذللوا له
# Expected Entities [('قرطبة', 'LOC')]
# Entities [('قرطبة', 'LOC')]
# 1  out of  1
#
# Text أبي لقمة وابن البن وطبقتهم بدمشق والفتح بن عبد السلام وطبقته
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text وجماعة وسكن المرية ثم استوطن قرطبة وأقرأ الناس بها وحدث وكان
# Expected Entities [('قرطبة', 'LOC')]
# Entities [('قرطبة', 'LOC')]
# 1  out of  1
#
# Text ويأخذ عكازا وكان من ظرفاء بغداد ومحتشميهم توفي سنة ست وتسعين
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text اليمن الكندي آخر ما كان ببغداد سنة ثلاث وستين وخمسمائة واستوطن
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text ودرس بالظاهرية وأفتى وأفاد توفي بدمشق بعد قدومه من الحج في
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text إنه ما رام يوما عن دمشق نزوحا ذهب الزمان وما ظفرت
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text على طارق ثم استخلف على الأندلس ولده عبد العزيز بن موسى
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text إسحاق بن إبراهيم الشهيدي دخلت الكوفة فأتيت ابن إدريس الأودي فأول
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text الموصل وقد بلغه ما جرى ببغداد من خلعه فقال له اكتب
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text أبو بكر الوفاة ه شاعر الأندلس ورأس شعراء الدولة العامرية صنف
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text كان ملك العلماء في وقته بإصبهان  محمد بن علي بن
# Expected Entities [('بإصبهان', 'LOC')]
# Entities [('بإصبهان', 'LOC')]
# 1  out of  1
#
# Text هو وأبوه وأخوه عباس وولد بدمشق سنة ست أو سبع وأربعين
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text الليث بن نصر بن سيار بسمرقند فوجه ابن ماهان لحربه ابنه
# Expected Entities [('بسمرقند', 'LOC')]
# Entities [('بسمرقند', 'LOC')]
# 1  out of  1
#
# Text لا يوقف عليه كثرة ولد بنصيبين ونشأ بالعراق وقدم مصر شابا
# Expected Entities [('بنصيبين', 'LOC')]
# Entities [('بنصيبين', 'LOC')]
# 1  out of  1
#
# Text أبو معمر الوفاة ه حدث ببغداد عن عبد الأعلى بن عبد
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text الصوفيه وجمع منها الكثير ورد نيسابور سنة أربعين وثلاثمائة والمشايخ متوافرون
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text بن محمد بن نباتة إلى بغداد في سنة أربع وثمانين ليتنجز
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text عمرو الباقلاني الوفاة ه الزاهد ببغداد كان ملازما للوحدة كان يكون
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text ه من أهل باب المراتب ببغداد شيخ صالح صحيح السماع سمع
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text العاص الأموي الوفاة ه نزيل الكوفة عن معاوية بن إسحاق وعمر
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text كان ينزل القسامل إحدى محال البصرة ولد سنة أربعمائة وسمع بالبصرة
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text قال قرأت على قبر سيبويه بشيراز هذه الأبيات وهي لسليمان بن
# Expected Entities [('بشيراز', 'LOC')]
# Entities [('بشيراز', 'LOC')]
# 1  out of  1
#
# Text بن منده وقت قدومه من خراسان سنة إحدى وسبعين يقول وعنده
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text أعلم الناس بأمور الناس وأخبار الكوفة وما كان أرواه عن هشام
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text واليا من قبل عمر على البصرة فأتى يزيد بن المهلب يسلم
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text سعيد محمد بن يوسف إلى أردبيل لعمارة الحصون التي خربها بابك
# Expected Entities [('أردبيل', 'LOC')]
# Entities [('أردبيل', 'LOC')]
# 1  out of  1
#
# Text الطبني الأديب الوفاة ه نزيل الأندلس قيل إنه لم يدخل الأندلس
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text من ابن اللتي بالكرك وقدم دمشق فقرأ القراءات على السخاوي وسمع
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text أبو الجيش خمارويه يتنزه بمرج دمشق بعذرا فغنى له المغني صوتا
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text قال لما ظهر المختار الكذاب بالكوفة هرب منه ناس فقدموا علينا
# Expected Entities [('بالكوفة', 'LOC')]
# Entities [('بالكوفة', 'LOC')]
# 1  out of  1
#
# Text الحواري وأظنه كان من الصالحين بدمشق  د ن أحمد بن
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text المختار الرقي الوفاة ه نزيل دمشق روى عن أبي بكر الأجري
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الطيب الفارقي وقد وزر لصاحب ميافارقين أحمد بن مروان ومن شعره
# Expected Entities [('ميافارقين', 'LOC')]
# Entities [('ميافارقين', 'LOC')]
# 1  out of  1
#
# Text يفعله إذ جاءه رجل من قرطبة فقال رأيت هشاما المؤيد بالله
# Expected Entities [('قرطبة', 'LOC')]
# Entities [('قرطبة', 'LOC')]
# 1  out of  1
#
# Text بحسن تدبير وزيرها فأرسل إليه خوارزم شاة يقول إنك وعدت عسكري
# Expected Entities [('خوارزم', 'LOC')]
# Entities [('خوارزم', 'LOC')]
# 1  out of  1
#
# Text المصري وأبي سعد المطرز وولد بنيسابور إذ أبوه بها وحضر عند
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text أنه كتب في ذلك إلى بغداد يسأل عن وفاة الكسائي فكان
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text الوفاة ه صحابي معروف نزل الكوفة وله رواية وعنه ابن أخيه
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text إسماعيل ابن السمرقندي وغيرهما ووعظ ببغداد ونفق سوقه وزادت حشمته وأملاكه
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text المروزي صاحب علي بن حجر ببغداد وعن مكي وابن الشرقي وعنه
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text الصوفية في رباط فيروزاباد بظاهر هراة أربعين سنة سمع بطبس أبا
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text الوفاة ه بصري ثقة حدث ببغداد عن روح بن عبادة وأبي
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text أحد الشعراء الكبار والنحاة المحققين ببغداد روى عن مهيار الديلمي ديوانه
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text زيادة وفي صفر وصل إلى بغداد ثلاثة عشر نجابا نفذهم صلاح
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text إلى بغداد كتب إلى أهل الموصل بالصحيح من أحاديث كان أخطأ
# Expected Entities [('الموصل', 'LOC')]
# Entities [('الموصل', 'LOC')]
# 1  out of  1
#
# Text سمع من يحيى الثقفي وحدث بدمشق وحلب وتوفي في حلب ليلة
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text كوفي مات بالرملة قلت حدث ببغداد ودمشق وحمص ومصر وحلب والرملة
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text على رأس أربعين سنة فأقام بمكة عشرا وبالمدينة عشرا وتوفي على
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text من فاطمة الجوزدانية وحدث عنها ببغداد روى عنه الحافظ الضياء وسمع
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بالشام وعبد الله بن فارس بأصبهان وعنه أبو الحسين بن جميع
# Expected Entities [('بأصبهان', 'LOC')]
# Entities [('بأصبهان', 'LOC')]
# 1  out of  1
#
# Text ولد سنة خمس وخمسمائة وتوفي بمكة قلت حدث ببغداد ودمشق روى
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text أجيب سيف الدولة إلا من أنطاكية ليذهب من الشام فإنه لنا
# Expected Entities [('أنطاكية', 'LOC')]
# Entities [('أنطاكية', 'LOC')]
# 1  out of  1
#
# Text توفي بعد الأربعين وقد حدث ببغداد  عبد السلام بن أحمد
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text مولى بني أمية وعالم أهل مكة وكان أحد أوعية العلم وهو
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text أبا بكر الشافعي وبجرجان الإسماعيلي وبإصبهان أبا الشيخ وخلقا سواهم بعدة
# Expected Entities [('وبإصبهان', 'LOC')]
# Entities [('وبإصبهان', 'LOC')]
# 1  out of  1
#
# Text النيسابوري الجوهري الوفاة ه نزيل بغداد قال حضرت مجلس أبي بكر
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text بقي إلا الرحلة إلى عبدان بخراسان وقال الحاكم هو إمام بلده
# Expected Entities [('بخراسان', 'LOC')]
# Entities [('بخراسان', 'LOC')]
# 1  out of  1
#
# Text رئيسا عالما من وزراء أمراء الأندلس وكان فصيحا مفوها شاعرا توفي
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text بن دينار من الأبناء والأبناء بمكة وباليمن من أولاد الفرس قال
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text قال عبد الغافر ثقة قدم نيسابور وحدث عن عبد الله بن
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text قضاء الشوبك مدة ثم سكن دمشق وولي القضاء بأماكن وخرج له
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الوفاة ه من أهل كرخ بغداد وقيل كنيته أبو الحسن وكان
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text طاهر بن بابشاذ وسمع الصحيح بمكة من كريمة وسمع من عبد
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text فلم يفتده أحد فقتل بظاهر أنطاكية رحمه الله وكان صدوقا متحريا
# Expected Entities [('أنطاكية', 'LOC')]
# Entities [('أنطاكية', 'LOC')]
# 1  out of  1
#
# Text ه العبد الصالح رحل وسمع ببغداد من يوسف القاضي وطبقته وعنه
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text الخواشتي الحافظ الوفاة ه نزيل هراة سمع أبا كريب وأحمد بن
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text سعد العوفي فأسرعوا حتى دخلوا مكة فكبروا تكبيرة سمعها ابن الزبير
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text الوازع البزاز الوفاة ه حدث ببغداد عن محمد بن أبان الواسطي
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بني سعد بن بكر إلى البصرة وكان ردءا للمسلمين فسار إلى
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text الفقيه الوفاة ه رئيس المطوعة بخراسان سمع أباه وعبد الله بن
# Expected Entities [('بخراسان', 'LOC')]
# Entities [('بخراسان', 'LOC')]
# 1  out of  1
#
# Text أن ينتقل إلى واسط أو البصرة واعتقلوه وأنزلوه سميرية وابتلت ثيابه
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text ابن عساكر وقال ولي الاستيفاء بدمشق وولد بصور سنة سبع وأربعين
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text بالمحمدي الوفاة ه الذي قدم دمشق بشيرا بكسرة التتار على عين
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text وأحضره وأمره بالخروج وفيها كانت بدمشق فتنة الحافظ عبد الغني بينه
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text أنس بن مالك غير مرة بالكوفة إذ قدمها أنس قاله ابن
# Expected Entities [('بالكوفة', 'LOC')]
# Entities [('بالكوفة', 'LOC')]
# 1  out of  1
#
# Text الدولة العباسية أصله من بلدة سلمية ومولده بحمص وقيل إنه لم
# Expected Entities [('سلمية', 'LOC')]
# Entities [('سلمية', 'LOC')]
# 1  out of  1
#
# Text ويروى أن السندي هدم سور دمشق وقد ضرب رجلا طويل اللحية
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text من بلاد الساحل للعادل وتكون عكا لأخت ملك الأنكتير مضافا إلى
# Expected Entities [('عكا', 'LOC')]
# Entities [('عكا', 'LOC')]
# 1  out of  1
#
# Text بن يوسف الهواري قاضي الجماعة بمراكش وخطيبها يكني أبا يوسف الوفاة
# Expected Entities [('بمراكش', 'LOC')]
# Entities [('بمراكش', 'LOC')]
# 1  out of  1
#
# Text تمهن الجواد وضعف عن سلطنة دمشق وقايض الملك الصالح نجم الدين
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text طلب الحديث بالحجاز واليمن والعراق وخراسان وقيل إنه مات سنة سبع
# Expected Entities [('وخراسان', 'LOC')]
# Entities [('وخراسان', 'LOC')]
# 1  out of  1
#
# Text الله بن طاوس وجماعة ودخل نيسابور فسمع من عبد المنعم بن
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text ومحمد ابن المحب وغيرهم وحدث بدمشق ومصر ومات في ثامن عشر
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text يتألفه فلم يهتز لذلك وقدم بغداد ونازلها بإزاء دار الخليفة فوجل
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text ورد أبو الحارث البساسيري إلى بغداد من الوقعة مع بني خفاجة
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text نظمه وعاش تسعين سنة وكان ببغداد  المظفر بن عبيد الله
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text إسحاق المروزي الوفاة ه حدث ببغداد عن الليث بن سعد وشريك
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بلنسية واستقاموا وتفقهوا استقدم إلى مراكش لتولي قضاة مرسية بعد وفاة
# Expected Entities [('مراكش', 'LOC')]
# Entities [('مراكش', 'LOC')]
# 1  out of  1
#
# Text ولا ريب أنها عظيمة وورد بغداد رسول صلاح الدين وهو مبارز
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text وأبو حفص عمر الفرغولي وتوفي بمكة هذه السنة  عبد السلام
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text الله بن محمد الضرير المقرئ ببغداد الوفاة ه كان رجلا صالحا
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text الشيخ وأحمد بن بندار وأهل أصبهان  إسحاق بن إبراهيم بن
# Expected Entities [('أصبهان', 'LOC')]
# Entities [('أصبهان', 'LOC')]
# 1  out of  1
#
# Text فسمع من ابن كليب وسكن بغداد وخطب بها ببعض الجوامع وكان
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text أبو شامة استولى المسعود على مكة وبنى القبة على مقام إبراهيم
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text زكريا التبريزي اللغوي قال دخلت دمشق فكنت أقرأ على الخطيب بحلقته
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text وتجدد دخول الأكراد المتلصصة إلى بغداد وأخذوا خيل الأتراك من الإصطبلات
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text بن عمار الذي كان صاحب طرابلس فحسن أيضا لمسعود الخروج على
# Expected Entities [('طرابلس', 'LOC')]
# Entities [('طرابلس', 'LOC')]
# 1  out of  1
#
# Text خرميك الغوري الذي صار صاحب هراة بعد وكان شجاعا مذكورا فساروا
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text النرسي جزءا عن شيوخه وقدم بغداد تاجرا غير مرة روى عنه
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text قرأ بواسط على غلام الهراس وببغداد على أبي بكر محمد بن
# Expected Entities [('وببغداد', 'LOC')]
# Entities [('وببغداد', 'LOC')]
# 1  out of  1
#
# Text عند القضاة وكان يعرف شيوخ دمشق ومروياتهم ويسمع العالي والنازل وخطه
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text جمال الدين أبو الدر ياقوت ببغداد في هذه السنة  يوسف
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بن السائب المخزومي أصله من همذان أسلم على يد السائب بن
# Expected Entities [('همذان', 'LOC')]
# Entities [('همذان', 'LOC')]
# 1  out of  1
#
# Text لي عليه جزءا وحدثنا عنه ببغداد عبد الوهاب الأنماطي والمبارك بن
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text معين سويد واسطي انتقل إلى دمشق ليس حديثه بشيء كان يقضي
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text من أين أنت قلت من نيسابور فقال من تقدمون من الرجلين
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text وكاتب الأتابك زنكي ليسلم إليه دمشق ففتكوا به في دهليز قلعة
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text فكانوا يشنون الغارات إلى باب دمشق فيقتلون ويأسرون وجعل للفرنج على
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text إلى العراق ليدبر أمورها فقدم بغداد وزينت له فغرق جماعة ومنع
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text صاحب الموصل قد وصل ألى دمشق لمعونة الأتابك طغتكين فتلقاه وسر
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الإخشيد حلب وفيها عظم الغلاء ببغداد حتى هرب الناس وبقي النساء
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text السلطان عصيان صاحب ماردين وصاحب دمشق غضب وبعث الجيوش لحربهما فساروا
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text في جمادى الآخرة ولم يخلف بما وراء النهر مثله قلت روى
# Expected Entities [('بما', 'LOC')]
# Entities [('بما', 'LOC')]
# 1  out of  1
#
# Text بن سليم وفيها ولي إمرة خراسان منصور بن يزيد بن منصور
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text قصيدة مدح بها بعض الناس بدمشق يقول بأي حكم دم العشاق
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text علي بن مت الأنصاري شيخ هراة أبو عطية الوفاة ه ابن
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text سنة أربع وأربعين وثلاثمائة وقدم بغداد سنة أربع وستين قال الخطيب
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text مالا فلم يقبله وقدم أبي بأصبهان إلى الخشبة ليصلب عليها بعد
# Expected Entities [('بأصبهان', 'LOC')]
# Entities [('بأصبهان', 'LOC')]
# 1  out of  1
#
# Text وكان من كبار قومه نزل الكوفة روى عنه قيس بن أبي
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text عنه بالإجازة عبد الرحمن المكبر ببغداد توفي في الثالث والعشرين من
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text عامله أن يولي يحيى قضاء نيسابور فقال يحيى للأمير قل لأمير
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text البغدادي المقرئ الوفاة ه نزيل دمشق قرأ على أبي بكر بن
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text مصر وأحد الفقهاء المالكية سمع بقرطبة قديما من إسماعيل بن إسحاق
# Expected Entities [('بقرطبة', 'LOC')]
# Entities [('بقرطبة', 'LOC')]
# 1  out of  1
#
# Text بن صالح العجلي نزيل أطرابلس المغرب ومحمد بن سحنون الإفريقي وبقي
# Expected Entities [('المغرب', 'LOC')]
# Entities [('المغرب', 'LOC')]
# 1  out of  1
#
# Text ذكاء وسكن بلاد العجم مدة بأذربيجان ونواحيها ومات قبل أن يتكهل
# Expected Entities [('بأذربيجان', 'LOC')]
# Entities [('بأذربيجان', 'LOC')]
# 1  out of  1
#
# Text ابني فإنا نخشى عليه وباء مكة قالت ونحن أضن شيء به
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text بن جابر وتربان من قرى سمرقند  موسى بن العباس أبو
# Expected Entities [('سمرقند', 'LOC')]
# Entities [('سمرقند', 'LOC')]
# 1  out of  1
#
# Text وثلاثمائة عملت الرافضة يوم عاشوراء ببغداد وناحت وفيها مات معز الدولة
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text وقال الحافظ المنذري كان مولده بأستوا بخبوشان في رجب سنة عشر
# Expected Entities [('بأستوا', 'LOC')]
# Entities [('بأستوا', 'LOC'), ('بخبوشان', 'LOC')]
# 1  out of  1
#
# Text أمواله وقتله وحمل رأسه إلى بغداد صحبة رسوله فأبرز للقية الموكب
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# ...
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text من العرب حتى رجعت إلى بغداد فقال لي الشيخ أبو إسحاق
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text يحيى قال كان حبيب يرى بالبصرة يوم التروية ويوم عرفة بعرفة
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text استوعب ابن عساكر في تاريخ دمشق أخباره وأحواله قال حسين المعلم
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text البغدادي البزاز الوفاة ه نزيل نيسابور عن علي بن عاصم ويزيد
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text معاوية عقبة بن نافع إلى إفريقية فخط القيروان وأقام بها ثلاث
# Expected Entities [('إفريقية', 'LOC')]
# Entities [('إفريقية', 'LOC')]
# 1  out of  1
#
# Text وفي هذه السنة حدث وكيع بمكة عن إسماعيل عن البهي وذكر
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text أبي بكر ابن الباقلاني إلى بغداد يسأله أن يرسل إلى دمشق
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text وتكاثفت أيضا جموع المنتصر وقصد نيسابور وحارب أميرها نصر بن سبكتكين
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text الفضل النوفلي الوفاة ه حدث ببغداد وغيرها عن خالد بن يزيد
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text عدة أماكن وجاء الصريخ إلى بغداد فانحدر سعد الدولة كوهرائين وسيف
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text الذكر المقدسي رئيس المؤذنين بجامع دمشق الوفاة ه ولد سنة سبع
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الضرير المقرئ الوفاة ه قدم دمشق وقرأ بها على أبي علي
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text ومحمد بن نصر ابن الحصري ببغداد والحسن بن عبد القاهر الشهرزوري
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text بانياس قويت نفوسهم وطمعوا في دمشق وحشدوا وتألبوا وتجمعوا من الرها
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text أنعم في بعض رسائله إلى بغداد بعشرة آلاف دينار أميرية على
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text فحدث بقطعة كبيرة منه ببعلبك وبنابلس وبجامع دمشق وكان إماما في
# Expected Entities [('وبنابلس', 'LOC')]
# Entities [('وبنابلس', 'LOC')]
# 1  out of  1
#
# Text وفيها كان خروج يوسف البرم بخراسان منكرا على المهدي الحالة التي
# Expected Entities [('بخراسان', 'LOC')]
# Entities [('بخراسان', 'LOC')]
# 1  out of  1
#
# Text وجه به عمر قاضيا على البصرة وبقي سنة لا يقبل بها
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text إسماعيل بن محمد بن الفضل بإصبهان كان عمر خريج أبي مسعود
# Expected Entities [('بإصبهان', 'LOC')]
# Entities [('بإصبهان', 'LOC')]
# 1  out of  1
#
# Text علي المقرئ الوفاة ه نزيل بغداد روى عن أحمد بن محمد
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text الحسن الضرير الوفاة ه كان ببغداد ذكر أنه من ولد عبد
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text محمد بن عبد الكريم الفرغاني وببغداد على أبي الخطاب ابن الجراح
# Expected Entities [('وببغداد', 'LOC')]
# Entities [('وببغداد', 'LOC')]
# 1  out of  1
#
# Text الأنصاري وأبي عبيدة ثم سكن بغداد ومدح الخلفاء والوزراء وكان رأسا
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text أم الحكم وبقي الضحاك على دمشق حتى هلك يزيد وعن عبد
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الأصبهاني وسمع من خلق كثير بهراة أصحاب الرفاء فمن بعدهم وصنف
# Expected Entities [('بهراة', 'LOC')]
# Entities [('بهراة', 'LOC')]
# 1  out of  1
#
# Text قلت هذا من كبار الرواة بقرطبة أجاز لابن مسدي  أحمد
# Expected Entities [('بقرطبة', 'LOC')]
# Entities [('بقرطبة', 'LOC')]
# 1  out of  1
#
# Text المفيد المحدث الوفاة ه نزيل بغداد أحد من عني بهذا الشأن
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text ه كان كثير الأسفار سمع بدمشق عبد الوهاب الكلابي وطلحة بن
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text من المواريث والمكوس وعقد ضمان بغداد على أبي سعد القايني بمائة
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text بالناس عتاب بن أسيد أمير مكة وقيل حج الناس أوزاعا حكاهما
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text الهروي الأزدي الوفاة ه قاضي هراة وابن قضاتها صار زعيم أصحاب
# Expected Entities [('هراة', 'LOC')]
# Entities [('هراة', 'LOC')]
# 1  out of  1
#
# Text عددا وعلى هذا طلبته المعتزلة بالبصرة عند السلطان ففر إلى بغداد
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text بن مجشر وخلق كثير سكن بغداد وانتهت إليه مشيخة العلم ببغداد
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text القرطبي المقرئ المالكي الزاهد المعروف بالأندلس بابن مغايظ الوفاة ه انتقل
# Expected Entities [('بالأندلس', 'LOC')]
# Entities [('بالأندلس', 'LOC')]
# 1  out of  1
#
# Text ه صاحب ابن الجلاء حدث بدمشق في هذه السنة عن أحمد
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text الشاهد لما مات إسماعيل مكثت بغداد ثلاثة أشهر ونصف بغير قاض
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text أخرى وكان في الغالب يصيف بالشام ويشتي بالديار المصرية قال وحاصل
# Expected Entities [('بالشام', 'LOC')]
# Entities [('بالشام', 'LOC')]
# 1  out of  1
#
# Text العقدة سنة أربعين وخمسمائة وصحب ببغداد الشيخ أبا النجيب السهروردي ولعله
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text مع صلاح الدين وغيره توفي بدمشق وورثه ابنه الأمير ظهير الدين
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text الله عنه وأقام بهرام له بدمشق خليفة يدعو إلى مذهبه فكثر
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text الحسن الحنفي الوفاة ه قدم بغداد وعظم شأنه حتى ولي قضاء
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text وغيرهم وشهد موت أبي الدرداء بدمشق قال حفص بن غياث عن
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text فورد عليه كتاب بتقليده قضاء البصرة فقال أشاور نفسي الليلة فغدونا
# Expected Entities [('البصرة', 'LOC')]
# Entities [('البصرة', 'LOC')]
# 1  out of  1
#
# Text قال الخطيب سمعته يقول ولدت بالبصرة في النصف من شعبان سنة
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text حنبل يقول لم يجئنا من خراسان مثل محمد بن إسماعيل وقال
# Expected Entities [('خراسان', 'LOC')]
# Entities [('خراسان', 'LOC')]
# 1  out of  1
#
# Text وتقلب في الخدم الديوانية بمصر ودمشق  والجزيرة وولي نظر الديوان
# Expected Entities [('ودمشق', 'LOC')]
# Entities [('ودمشق', 'LOC')]
# 1  out of  1
#
# Text مع أبي وأخي أحمد إلى مكة فلما حججت رجع أخي بها
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text أقسنقر البرسقي الذي كان شحنة بغداد قد أقطعه مراغة والرحبة وكان
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text استعدي عليه بقزوين وقدم علينا همذان سنة خمس وعشرين وثلاثمائة وقال
# Expected Entities [('همذان', 'LOC')]
# Entities [('همذان', 'LOC')]
# 1  out of  1
#
# Text الديلمي فعطف العبد بالعساكر فطلع بجرجان وتوقف بها إلى انصراف الشتاء
# Expected Entities [('بجرجان', 'LOC')]
# Entities [('بجرجان', 'LOC')]
# 1  out of  1
#
# Text قتل في أول سنة عشر ببغداد بدار السلطان وكان جالسا إلى
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text أي رسم أبطلت قال المكس بمكة فقلت أهذا وحده أبطلت قد
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text قراسنقر الأتابك الوفاة ه صاحب أذربيجان وأران من مماليك الملك طغرل
# Expected Entities [('أذربيجان', 'LOC')]
# Entities [('أذربيجان', 'LOC')]
# 1  out of  1
#
# Text قال الأبار وكان حافظا لأخبار الأندلس معنيا بالرجال ضابطا متقنا له
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text عمل نيابة حلب مدة ونيابة طرابلس وغير ذلك توفي بالساحل في
# Expected Entities [('طرابلس', 'LOC')]
# Entities [('طرابلس', 'LOC')]
# 1  out of  1
#
# Text بالمعتز شرحا مشبعا ودخل البروي بغداد فصادف قبولا وافرا وتوفي بعد
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text به فإن له ابنا كيسا بمكة فخرج ابنه المطلب سرا حتى
# Expected Entities [('بمكة', 'LOC')]
# Entities [('بمكة', 'LOC')]
# 1  out of  1
#
# Text معظما للآثار وما أراه قدم بغداد بل استناب عليها أربعة قضاة
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text والعشرين من شوال فحمل إلى إصبهان قال ابن الأثير وقعت لموته
# Expected Entities [('إصبهان', 'LOC')]
# Entities [('إصبهان', 'LOC')]
# 1  out of  1
#
# Text هبة الله قدم أبوه من كرمان وولد هو ببغداد ونظر في
# Expected Entities [('كرمان', 'LOC')]
# Entities [('كرمان', 'LOC')]
# 1  out of  1
#
# Text بن عبد الملك عن أرمينية وأذربيجان وأعيد الجراح بن عبد الله
# Expected Entities [('وأذربيجان', 'LOC')]
# Entities [('وأذربيجان', 'LOC')]
# 1  out of  1
#
# Text وكان أسند من بقي بأقطار الأندلس في زمانه  أحمد بن
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text الزاهدين توفي من البرد بطريق مكة روى عنه السلفي  أحمد
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text فكثر التعصب عليه فتوجه إلى شيراز وبنى له ملكها شرف الدين
# Expected Entities [('شيراز', 'LOC')]
# Entities [('شيراز', 'LOC')]
# 1  out of  1
#
# Text ذكر أبو يعلى حمزة أخذت طرابلس سنة ثلاث وخمسمائة قال ابن
# Expected Entities [('طرابلس', 'LOC')]
# Entities [('طرابلس', 'LOC')]
# 1  out of  1
#
# Text في صفر وعاد الأشرف إلى دمشق قال أبو شامة سمعت الصاحب
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text فلم يؤذن له في دخول بغداد فطلب وديعته فلم تحصل له
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text يعقوب التاجر الوفاة ه حدث بنيسابور عن علي بن حجر وأحمد
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text الموصلي أبو عبد الله قاضي بغداد مشاركا لأبي البركات جعفر الثقفي
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text فرغ من بناء المصلى بظاهر دمشق ورتب له خطيب وهو الشيخ
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text إلى اجتماعهما بمجير الدين صاحب دمشق فأنفذ يستدعي الرئيس للإصلاح بينهم
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text يتعصبون لأبي نعيم وكانوا رؤساء إصبهان سمعت الحافظ يقول كنا بالموصل
# Expected Entities [('إصبهان', 'LOC')]
# Entities [('إصبهان', 'LOC')]
# 1  out of  1
#
# Text البالسي الوفاة ه الإمام بمدينة أنطاكية وصاحب الجزء المعروف رحل وطوف
# Expected Entities [('أنطاكية', 'LOC')]
# Entities [('أنطاكية', 'LOC')]
# 1  out of  1
#
# Text وعنه ابنه عبد الملك شيخ مكة وخصيف الجزري قال البخاري لا
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text البقاع وجاءت طائفة على غوطة دمشق فنهبوا في القرى وسبوا وقتلوا
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text بن محمد اليونيني الزاهد أسد الشام رحمة الله عليه الوفاة ه
# Expected Entities [('الشام', 'LOC')]
# Entities [('الشام', 'LOC')]
# 1  out of  1
#
# Text بمذاهبهما توفي هذا في شعبان ببغداد قال ابن درستويه النحوي اجتمعت
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text مولاهم الحلبي الوفاة ه نزيل الأندلس سمع أبا الجهم بن طلاب
# Expected Entities [('الأندلس', 'LOC')]
# Entities [('الأندلس', 'LOC')]
# 1  out of  1
#
# Text وسمع مقدمة الجزولي عليه وقدم دمشق سنة عشر وسمع من الكندي
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الرحمن بن عبد العزيز السراج بدمشق قال أخبرنا أبو الحسن محمد
# Expected Entities [('بدمشق', 'LOC')]
# Entities [('بدمشق', 'LOC')]
# 1  out of  1
#
# Text بن أبي عمران التجيبي قاضي أفريقية وسالم أبو النضر المدني وعلي
# Expected Entities [('أفريقية', 'LOC')]
# Entities [('أفريقية', 'LOC')]
# 1  out of  1
#
# Text الله ومرثد اليزني وولي غزو إفريقية لمعاوية سنة ست وأربعين وقال
# Expected Entities [('إفريقية', 'LOC')]
# Entities [('إفريقية', 'LOC')]
# 1  out of  1
#
# Text راجعا للرائي وجاء الكتاب إلى دمشق بقصة هؤلاء يوم موت نور
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text الحسن الطبري الوفاة ه قاضي أصبهان كان رأسا في الفقه والحديث
# Expected Entities [('أصبهان', 'LOC')]
# Entities [('أصبهان', 'LOC')]
# 1  out of  1
#
# Text محمد بن إسماعيل ولم يخلف بخراسان مثل أبي عيسى في العلم
# Expected Entities [('بخراسان', 'LOC')]
# Entities [('بخراسان', 'LOC')]
# 1  out of  1
#
# Text وأبو سعيد النقاش الأصبهانيان لقياه ببغداد وله تاريخ كبير على السنين
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text الملك الفارقي بقراءتي ولم أر ببغداد من يدانيه في فضله ويضاهيه
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text رسل التتار يومئذ بحرستا فدخلوا دمشق وقرئ فرمان الملك بأمان أهل
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text كتاب مليح ذكر فيه أن طرابلس فتحت في إمرة معاوية وتنقلت
# Expected Entities [('طرابلس', 'LOC')]
# Entities [('طرابلس', 'LOC')]
# 1  out of  1
#
# Text الشر ثم نازل نور الدين أنطاكية وحاصرها إلى أن ذلوا وسلموها
# Expected Entities [('أنطاكية', 'LOC')]
# Entities [('أنطاكية', 'LOC')]
# 1  out of  1
#
# Text الضرير الحنبلي الوفاة ه تفقه ببغداد على أئمتها وسمع أبا الحسين
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text قال وسمعت أبي يقول وبقيت بالبصرة سنة أربع عشرة ثمانية أشهر
# Expected Entities [('بالبصرة', 'LOC')]
# Entities [('بالبصرة', 'LOC')]
# 1  out of  1
#
# Text وكتاب علوم الحديث و تاريخ إصبهان وكتاب الإخوة وكتاب العلم وكتاب
# Expected Entities [('إصبهان', 'LOC')]
# Entities [('إصبهان', 'LOC')]
# 1  out of  1
#
# Text بيهق وبيهق ناحية من أعمال نيسابور قصبتها خسروجرد ولد قبل الخمسين
# Expected Entities [('نيسابور', 'LOC')]
# Entities [('نيسابور', 'LOC')]
# 1  out of  1
#
# Text والدتي وهو من أماثل أهل أصبهان له أوقاف كثيرة في البلد
# Expected Entities [('أصبهان', 'LOC')]
# Entities [('أصبهان', 'LOC')]
# 1  out of  1
#
# Text ببغداد ويوم عاشوراء دخل عجيف بغداد بسبي الزط وأسراهم فعبأهم على
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text وبإربل من عمر بن طبرزد وبنيسابور من المؤيد بن محمد وبهراة
# Expected Entities [('وبنيسابور', 'LOC')]
# Entities [('وبنيسابور', 'LOC')]
# 1  out of  1
#
# Text خمس عشرة ومائة قال وولده بالأندلس إلى اليوم  ن ق
# Expected Entities [('بالأندلس', 'LOC')]
# Entities [('بالأندلس', 'LOC')]
# 1  out of  1
#
# Text القرامطة جراحاته وجاءت الأخبار إلى بغداد فخاف الناس وعسكر مؤنس بباب
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text العزيز بن بندار الشيرازي نزيل مكة وغيره ولقد أتى بمصائب يشهد
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text وثلاثمائة وتوفي في رمضان وأنا بنيسابور وله ثمانون سنة  محمد
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text بابن المنبور الوفاة ه سكن بغداد وأم بالنظامية وسمع أبا الحسين
# Expected Entities [('بغداد', 'LOC')]
# Entities [('بغداد', 'LOC')]
# 1  out of  1
#
# Text جماعة يعتسف البلاد حتى أتى مكة فتأتى له من ذلك ما
# Expected Entities [('مكة', 'LOC')]
# Entities [('مكة', 'LOC')]
# 1  out of  1
#
# Text عبد الله المحاملي وروى الكثير بنيسابور روى عنه الحاكم وقال توفي
# Expected Entities [('بنيسابور', 'LOC')]
# Entities [('بنيسابور', 'LOC')]
# 1  out of  1
#
# Text وفضائل بني العباس في جامع دمشق فكان ذلك سبب نفي الخطيب
# Expected Entities [('دمشق', 'LOC')]
# Entities [('دمشق', 'LOC')]
# 1  out of  1
#
# Text المديني توفي في ذي القعدة بأصبهان  الحسين بن ظفر بن
# Expected Entities [('بأصبهان', 'LOC')]
# Entities [('بأصبهان', 'LOC')]
# 1  out of  1
#
# Text بلده بخريبة الوفاة ه روى بالكوفة وبغداد عن الكبار سمع القاضي
# Expected Entities [('بالكوفة', 'LOC')]
# Entities [('بالكوفة', 'LOC')]
# 1  out of  1
#
# Text زاد من هيبته فرجع من الكوفة ولم يصل إليه قال يحيى
# Expected Entities [('الكوفة', 'LOC')]
# Entities [('الكوفة', 'LOC')]
# 1  out of  1
#
# Text ه حدث في هذا العام ببغداد عن عبد الله بن محمد
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Text الصاحب شمس الدين وعلاء الدين ببغداد فأحصيت الجوائز والصلات التي فرقا
# Expected Entities [('ببغداد', 'LOC')]
# Entities [('ببغداد', 'LOC')]
# 1  out of  1
#
# Accuracy 1.0
